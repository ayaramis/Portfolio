# %%
import numpy as np
import pandas as pd

# %%
list = ['Bacillus sp. Nf3 ASM302854v1 (GCF_003028545.1).tsv', ]
for i in list:
    df = pd.read_csv('i', sep='\t')
    df['Bacteria'] = 'i'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 list = ['Bacillus sp. Nf3 ASM302854v1 (GCF_003028545.1).tsv', ]
#       2 for i in list:
# ----> 3     df = pd.read_csv('i', sep='\t')
#       4     df['Bacteria'] = 'i'
#
# ...

# %%
df = pd.read_csv('Bacillus sp. Nf3 ASM302854v1 (GCF_003028545.1).tsv', sep='\t')
df['Bacteria'] = 'Bacillus sp. Nf3 ASM302854v1 (GCF_003028545.1)'
df1 = pd.read_csv('Klebsiella sp. A-Nf5 ASM281054v1 (GCF_002810545.1).tsv', sep='\t')
df1['Bacteria'] = 'Klebsiella sp. A-Nf5 ASM281054v1 (GCF_002810545.1)'
df2 = pd.read_csv('Klebsiella sp. B-Nf7 ASM281047v1 (GCF_002810475.1).tsv', sep='\t')
df2['Bacteria'] = 'Klebsiella sp. B-Nf7 ASM281047v1 (GCF_002810475.1)'

# %%
df.head()
# Out:
#            Accession  Begin   End  Chromosome Orientation  \
# 0  NZ_PYUA01000001.1      2    78         NaN        plus
# 1  NZ_PYUA01000001.1     83   159         NaN        plus
# 2  NZ_PYUA01000001.1    187   259         NaN        plus
# 3  NZ_PYUA01000001.1    607  1314         NaN        plus
# 4  NZ_PYUA01000001.1   1322  3160         NaN        plus
#
#                                                 Name Symbol  Gene ID  \
# 0                                           tRNA-Met    NaN      NaN
# 1                                           tRNA-Asp    NaN      NaN
# 2                                           tRNA-Phe    NaN      NaN
# 3                            response regulator YycF   yycF      NaN
# 4  cell wall metabolism sensor histidine kinase WalK   walK      NaN
#
#         Gene Type  Transcripts accession  Transcript name Protein accession  \
# 0            tRNA                    NaN              NaN               NaN
# ...

# %%
df.Name.nunique()
# Out:
# 2374

# %%
df[['Protein accession', 'Name']]
# Out:
#      Protein accession                                               Name
# 0                  NaN                                           tRNA-Met
# 1                  NaN                                           tRNA-Asp
# 2                  NaN                                           tRNA-Phe
# 3       WP_024424030.1                            response regulator YycF
# 4       WP_107162790.1  cell wall metabolism sensor histidine kinase WalK
# ...                ...                                                ...
# 3866    WP_219909146.1                               hypothetical protein
# 3867    WP_219909148.1                               hypothetical protein
# 3868    WP_142398099.1  RHS repeat-associated core domain-containing p...
# 3869    WP_142398100.1         fimbria/pilus outer membrane usher protein
# 3870    WP_142398101.1                      amidohydrolase family protein
#
# [3871 rows x 2 columns]

# %%
df.shape
# Out:
# (3871, 16)

# %%
pd.concat([df,df1,df2], axis=0).head(3)
# Out:
#            Accession  Begin  End  Chromosome Orientation      Name Symbol  \
# 0  NZ_PYUA01000001.1      2   78         NaN        plus  tRNA-Met    NaN
# 1  NZ_PYUA01000001.1     83  159         NaN        plus  tRNA-Asp    NaN
# 2  NZ_PYUA01000001.1    187  259         NaN        plus  tRNA-Phe    NaN
#
#    Gene ID Gene Type  Transcripts accession  Transcript name  \
# 0      NaN      tRNA                    NaN              NaN
# 1      NaN      tRNA                    NaN              NaN
# 2      NaN      tRNA                    NaN              NaN
#
#   Protein accession Protein name  Protein length      Locus tag  \
# 0               NaN          NaN             NaN  C9414_RS00005
# 1               NaN          NaN             NaN  C9414_RS00010
# 2               NaN          NaN             NaN  C9414_RS00015
#
#                                          Bacteria
# 0  Bacillus sp. Nf3 ASM302854v1 (GCF_003028545.1)
# 1  Bacillus sp. Nf3 ASM302854v1 (GCF_003028545.1)
# ...

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3871 entries, 0 to 3870
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Accession              3871 non-null   object
#  1   Begin                  3871 non-null   int64
#  2   End                    3871 non-null   int64
#  3   Chromosome             0 non-null      float64
#  4   Orientation            3871 non-null   object
#  5   Name                   3871 non-null   object
#  6   Symbol                 956 non-null    object
#  7   Gene ID                0 non-null      float64
#  8   Gene Type              3871 non-null   object
#  9   Transcripts accession  0 non-null      float64
#  10  Transcript name        0 non-null      float64
#  11  Protein accession      3768 non-null   object
#  12  Protein name           3768 non-null   object
#  13  Protein length         3768 non-null   float64
# ...

# %%
a = df.loc[:, ['Genus', 'Species', 'NCBI GenBank ID', 'Ecosystem', 'Cell Shape',
       'Cultured', 'Diseases', 'Gram Staining', 'Metabolism', 'Motility',
       'Oxygen Requirement', 'Phenotype', 'Sporulation', 'Temperature Range',
       'Habitat', 'Isolation Country', 'Latitude', 'Longitude',
       'Nitrate Concentration', 'Oxygen Concentration', 'pH', 'Pressure',
       'Salinity', 'Genome Size   * assembled', 'Gene Count   * assembled',
       'CRISPR Count   * assembled', 'GC   * assembled',
       'CDS Count   * assembled', 'RNA Count   * assembled',
       'rRNA Count   * assembled', '5S rRNA Count   * assembled',
       '16S rRNA Count   * assembled', '18S rRNA Count   * assembled',
       '23S rRNA Count   * assembled', '28S rRNA Count   * assembled',
       'tRNA Count   * assembled', 'Other RNA Count   * assembled',
       'Unchar Count ', 'w/ Func Pred Count   * assembled',
       'w/o function prediction  * assembled', 'Enzyme Count   * assembled',
       'KEGG Count   * assembled', 'Not KEGG Count   * assembled',
       'Estimated Number of Genomes  * assembled',
       'Estimated Average Genome Size  * assembled', 'Unnamed: 52']]

# %%
a.Genus = a.Genus.str.title()
a['NCBI GenBank ID'].isnull().sum()
# Out:
# 122

# %%
a.Ecosystem.isnull().sum()
# Out:
# 333

# %%
a['Cell Shape'].isnull().sum()
# Out:
# 1443

# %%
a.Cultured.isnull().sum()
# Out:
# 0

# %%
a[a.Diseases.notnull()]
# Out:
#               Genus                               Species  \
# 136    Liberibacter  Candidatus Liberibacter solanacearum
# 398    Liberibacter     Candidatus Liberibacter asiaticus
# 611       Rhizobium               Rhizobium leguminosarum
# 636   Agrobacterium                  Agrobacterium fabrum
# 1176  Allorhizobium               Allorhizobium ampelinum
# 1491   Liberibacter     Candidatus Liberibacter asiaticus
#
#                                         NCBI GenBank ID        Ecosystem  \
# 136                                            CP002371  Host-associated
# 398                                            CP004005              NaN
# 611                                     JASCRK000000000  Host-associated
# 636              AE007871, AE007870, AE007869, AE007872  Host-associated
# 1176  CP000637, CP000635, CP000633, CP000639, CP0006...  Host-associated
# 1491                                           CP001677  Host-associated
#
# ...

# %%
a['Gram Staining'].isnull().sum()
# Out:
# 1362

# %%
a[a['NCBI GenBank ID'].notnull()]
# Out:
#               Genus                    Species  \
# 8     Mesorhizobium  Mesorhizobium sp. B2-4-13
# 9         Rhizobium         Rhizobium sp. FY34
# 10    Agrobacterium    Agrobacterium deltaense
# 11          Ensifer        Ensifer sp. WSM1721
# 12     Liberibacter      Liberibacter crescens
# ...             ...                        ...
# 1536  Agrobacterium       Agrobacterium fabrum
# 1537      Rhizobium          Rhizobium sp. M10
# 1538  Mesorhizobium   Mesorhizobium sp. B3-2-1
# 1539        Ensifer      Ensifer sp. SEMIA 134
# 1541  Mesorhizobium   Mesorhizobium sp. B1-1-1
#
#                                        NCBI GenBank ID        Ecosystem  \
# 8                                         VFVB00000000    Environmental
# 9                                         STFZ00000000  Host-associated
# 10                                        RRZI00000000  Host-associated
# 11                                        AZUW00000000  Host-associated
# ...

# %%
a['NCBI GenBank ID'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: NCBI GenBank ID, dtype: object

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1542 entries, 0 to 1541
# Data columns (total 46 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Genus                                       1542 non-null   object
#  1   Species                                     1542 non-null   object
#  2   NCBI GenBank ID                             1420 non-null   object
#  3   Ecosystem                                   1209 non-null   object
#  4   Cell Shape                                  99 non-null     object
#  5   Cultured                                    1542 non-null   object
#  6   Diseases                                    6 non-null      object
#  7   Gram Staining                               180 non-null    object
#  8   Metabolism                                  89 non-null     object
#  9   Motility                                    94 non-null     object
# ...
